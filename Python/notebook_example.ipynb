# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
villes = [ "Toulouse", "Pau", "Bordeaux" ]
villes
# Out:
# ['Toulouse', 'Pau', 'Bordeaux']

# %%
values = np.random.normal(10, 4, 1000)
values
# Out:
# array([ 6.6080404 , 11.34521187,  6.06507894, 15.51675626, 13.2679254 ,
#         9.28817905,  6.1477023 , 15.59087195,  0.58934618, 11.63080562,
#         6.90432612, 16.20081074, 19.37891814,  5.470927  , 13.09704875,
#         7.67166798, 15.52571489,  8.77483163,  8.60234677,  6.45695677,
#         8.46866366,  5.06311513,  5.66332045, 11.2062284 ,  6.55577568,
#         0.47541795, 13.03723058, 14.14913527,  9.41897926, 10.01277351,
#         9.92410266,  8.2722596 ,  9.40884126,  9.04027075, 15.45322289,
#         8.08280501, 13.31851294, 11.97580907,  6.84412454, 10.63505634,
#         5.66436929, 19.38342582,  7.71132135, 13.89407812, 17.7991731 ,
#        14.83876228, 17.57777019, 20.30721399, 15.02344429, 12.48249184,
#        17.28738159,  6.61402355,  6.86698626, 19.53188135, 17.5492303 ,
#        12.36321615, 11.68980525,  7.89229463,  5.69319848,  5.79095195,
#         4.50645774, 10.9267903 ,  7.51970286, 10.32877928, 16.40675684,
# ...

# %%
plt.plot(values)

# %%
plt.hist(values)
# Out:
# (array([ 10.,  33.,  83., 157., 217., 214., 156.,  79.,  36.,  15.]),
#  array([-1.33149739,  0.93481623,  3.20112984,  5.46744345,  7.73375706,
#         10.00007068, 12.26638429, 14.5326979 , 16.79901151, 19.06532513,
#         21.33163874]),
#  <BarContainer object of 10 artists>)
